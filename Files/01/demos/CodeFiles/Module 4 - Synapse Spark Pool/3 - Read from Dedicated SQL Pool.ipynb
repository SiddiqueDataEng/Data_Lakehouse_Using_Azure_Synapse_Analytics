// %%
%%spark
val df = spark.read.synapsesql("TaxiWarehouse.main.YellowTaxis") 

val yellowTaxis = df.where("trip_distance > 10")

display(yellowTaxis)
// Out:
// StatementMeta(PSSparkPool, 2, 3, Finished, Available)
// df: org.apache.spark.sql.DataFrame = [VendorID: int, tpep_pickup_datetime: timestamp ... 16 more fields]
// yellowTaxis: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [VendorID: int, tpep_pickup_datetime: timestamp ... 16 more fields]
// SynapseWidget(Synapse.DataFrame, 3ad1d244-4710-40bb-a497-de260095bd19)
